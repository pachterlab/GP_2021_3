# %% [markdown]
# # 10x neuron fit, whole-dataset, no noise

# %% [markdown]
# In this notebook, we fit a model with bursty transcription, splicing, and degradation, without integrating a model of technical noise. We analyze the three 10x neuron datasets.

# %% [markdown]
# ## Prerequisites

# %% [markdown]
# Load in *Monod*.

# %%
import sys
sys.path.insert(0, '/home/ggorin/projects/monod/src/')

# %%
import monod
from monod import preprocess, extract_data, cme_toolbox, inference, analysis

# %% [markdown]
# ## Metadata

# %% [markdown]
# Define metadata and directories.

# %%
dataset_meta = ['neuron_' + x for x in ['1k_v2','1k_v3','10k_v3']]

dataset_names = [x for x in dataset_meta ]  
raw_data_locations = [x for x in dataset_meta]
transcriptome_filepath = '../polyA_ref/gg_200524_mouse_genome_polyA_cum_1'

spliced_layer = 'spliced'
unspliced_layer = 'unspliced'
gene_attr = 'gene_name'
cell_attr = 'barcode'

attribute_names=[(unspliced_layer,spliced_layer),gene_attr,cell_attr]

loom_filepaths = ['/home/ggorin/count_data/loom_10x_kb/'+x+'.loom' for x in raw_data_locations] 
n_datasets = len(loom_filepaths)

# %%
dataset_names
# Out:
# ['neuron_1k_v2', 'neuron_1k_v3', 'neuron_10k_v3']

# %% [markdown]
# ## Filtering

# %% [markdown]
# Perform a round of filtering based on the knee plot.

# %%
import pandas as pd
import numpy as np
import loompy as lp
import matplotlib.pyplot as plt
import scipy

# %%
cf = []
thr_lb = [8e2,1e3,1e3]
S_arr = []
U_arr = []
fig1,ax1 = plt.subplots(1,3,figsize=(15,4))

for k in range(len(dataset_meta)):
# for k in range(1):
    filename = loom_filepaths[k ]
    dataset_name = raw_data_locations[k ]
        
    with lp.connect(filename,mode='r') as ds:
        S = ds.layers[spliced_layer][:]
        U = ds.layers[unspliced_layer][:]
        gene_names = ds.ra[gene_attr]
        bcs = ds.ca[cell_attr]
        n_cells = S.shape[1]
        monod.preprocess.knee_plot(S+U,ax1[k],viz=True,thr=thr_lb[k])
        cf_ = ((S+U).sum(0)>thr_lb[k])
        
        print(f'Dataset {dataset_name}. \n\t{len(bcs)} barcodes in loom, {cf_.sum()} pass filter.')
#         
        S_arr.append(S)
        U_arr.append(U)

        cf.append(cf_)

    ax1[k].set_title(dataset_name)
# Out:
# Dataset neuron_1k_v2.
# 	1265 barcodes in loom, 1228 pass filter.
# Dataset neuron_1k_v3.
# 	1330 barcodes in loom, 1301 pass filter.
# Dataset neuron_10k_v3.
# 	11954 barcodes in loom, 11873 pass filter.

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# Create a batch and select genes to analyze.

# %%
import logging, sys
logging.basicConfig(stream=sys.stdout)
log = logging.getLogger()
log.setLevel(logging.INFO)

# %%
dir_string,dataset_strings = monod.preprocess.construct_batch(loom_filepaths, \
                                             transcriptome_filepath, \
                                             dataset_names, \
                                             attribute_names=attribute_names,\
                                             batch_location='./fits',meta='neuron_noisefree',batch_id=1,\
                                             n_genes=2500,exp_filter_threshold=None,cf=cf)
# Out:
# INFO:root:Beginning data preprocessing and filtering.
# INFO:root:Directory ./fits/gg_221119_025_neuron_noisefree_1 created.
# INFO:root:Dataset: neuron_1k_v2
# INFO:root:1228 cells detected.
# INFO:root:32285 features observed, 32005 match genome annotations. 31649 were unique.
# INFO:root:2004 genes retained after expression filter.
# INFO:root:Directory ./fits/gg_221119_025_neuron_noisefree_1/neuron_1k_v2 created.
# INFO:root:Dataset: neuron_1k_v3
# INFO:root:1301 cells detected.
# INFO:root:32285 features observed, 32005 match genome annotations. 31649 were unique.
# INFO:root:4960 genes retained after expression filter.
# INFO:root:Directory ./fits/gg_221119_025_neuron_noisefree_1/neuron_1k_v3 created.
# INFO:root:Dataset: neuron_10k_v3
# INFO:root:11873 cells detected.
# INFO:root:32285 features observed, 32005 match genome annotations. 31649 were unique.
# INFO:root:5365 genes retained after expression filter.
# INFO:root:Directory ./fits/gg_221119_025_neuron_noisefree_1/neuron_10k_v3 created.
# INFO:root:Total of 2500 genes selected.
# WARNING:root:Selecting 2500 genes required 66.7% dataset threshold.
# INFO:root:Directory ./fits/gg_221119_025_neuron_noisefree_1/diagnostic_figures created.

# %% [markdown]
# ## Inference

# %% [markdown]
# Fit the model.

# %%
import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)

# %%
phys_lb = [-1.0, -1.8, -1.8 ]
phys_ub = [4.2, 2.5, 3.5]
samp_lb = [1,1]
samp_ub = [1,1]
gridsize = [1,1]



result_strings = []
for i in range(n_datasets):
    fitmodel = monod.cme_toolbox.CMEModel('Bursty','None')
    inference_parameters = monod.inference.InferenceParameters(phys_lb,phys_ub,samp_lb,samp_ub,gridsize,\
                dataset_strings[i],fitmodel,use_lengths = False,
                gradient_params = {'max_iterations':15,'init_pattern':'moments','num_restarts':1})
    search_data = monod.extract_data.extract_data(loom_filepaths[i], transcriptome_filepath, dataset_names[i],
                dataset_strings[i], dir_string, dataset_attr_names=attribute_names,cf=cf[i])
    full_result_string = inference_parameters.fit_all_grid_points(1,search_data)
    result_strings.append(full_result_string)
# Out:
# INFO:root:Sequencing model set to None. All sampling parameters set to null.
# INFO:root:Directory ./fits/gg_221119_025_neuron_noisefree_1/neuron_1k_v2/Bursty_None_1x1 created.
# INFO:root:Global inference parameters stored to ./fits/gg_221119_025_neuron_noisefree_1/neuron_1k_v2/Bursty_None_1x1/parameters.pr.
# INFO:root:Beginning data extraction.
# INFO:root:Dataset: neuron_1k_v2
# INFO:root:32285 features observed, 32005 match genome annotations. 31649 were unique.
# INFO:root:Gene list extracted from ./fits/gg_221119_025_neuron_noisefree_1/genes.csv.
# INFO:root:Directory ./fits/gg_221119_025_neuron_noisefree_1/neuron_1k_v2/diagnostic_figures created.
# INFO:root:Search data stored to ./fits/gg_221119_025_neuron_noisefree_1/neuron_1k_v2/raw.sd.
# INFO:root:Starting non-parallelized grid scan.
# INFO:root:Non-parallelized grid scan complete.
# INFO:root:All grid point data cleaned from disk.
# INFO:root:Directory ./fits/gg_221119_025_neuron_noisefree_1/neuron_1k_v2/Bursty_None_1x1/analysis_figures created.
# INFO:root:Runtime: 68.2 seconds.
# INFO:root:Sequencing model set to None. All sampling parameters set to null.
# INFO:root:Directory ./fits/gg_221119_025_neuron_noisefree_1/neuron_1k_v3/Bursty_None_1x1 created.
# INFO:root:Global inference parameters stored to ./fits/gg_221119_025_neuron_noisefree_1/neuron_1k_v3/Bursty_None_1x1/parameters.pr.
# INFO:root:Beginning data extraction.
# INFO:root:Dataset: neuron_1k_v3
# INFO:root:32285 features observed, 32005 match genome annotations. 31649 were unique.
# INFO:root:Gene list extracted from ./fits/gg_221119_025_neuron_noisefree_1/genes.csv.
# INFO:root:Directory ./fits/gg_221119_025_neuron_noisefree_1/neuron_1k_v3/diagnostic_figures created.
# INFO:root:Search data stored to ./fits/gg_221119_025_neuron_noisefree_1/neuron_1k_v3/raw.sd.
# INFO:root:Starting non-parallelized grid scan.
# INFO:root:Non-parallelized grid scan complete.
# INFO:root:All grid point data cleaned from disk.
# INFO:root:Directory ./fits/gg_221119_025_neuron_noisefree_1/neuron_1k_v3/Bursty_None_1x1/analysis_figures created.
# INFO:root:Runtime: 182.8 seconds.
# INFO:root:Sequencing model set to None. All sampling parameters set to null.
# INFO:root:Directory ./fits/gg_221119_025_neuron_noisefree_1/neuron_10k_v3/Bursty_None_1x1 created.
# INFO:root:Global inference parameters stored to ./fits/gg_221119_025_neuron_noisefree_1/neuron_10k_v3/Bursty_None_1x1/parameters.pr.
# INFO:root:Beginning data extraction.
# INFO:root:Dataset: neuron_10k_v3
# INFO:root:32285 features observed, 32005 match genome annotations. 31649 were unique.
# INFO:root:Gene list extracted from ./fits/gg_221119_025_neuron_noisefree_1/genes.csv.
# INFO:root:Directory ./fits/gg_221119_025_neuron_noisefree_1/neuron_10k_v3/diagnostic_figures created.
# INFO:root:Search data stored to ./fits/gg_221119_025_neuron_noisefree_1/neuron_10k_v3/raw.sd.
# INFO:root:Starting non-parallelized grid scan.
# INFO:root:Non-parallelized grid scan complete.
# INFO:root:All grid point data cleaned from disk.
# INFO:root:Directory ./fits/gg_221119_025_neuron_noisefree_1/neuron_10k_v3/Bursty_None_1x1/analysis_figures created.
# INFO:root:Runtime: 129.9 seconds.

# %% [markdown]
# ## Post-processing

# %% [markdown]
# Load in data and do basic QC: test parameter trends and goodness-of-fit.

# %%
dataset_names
# Out:
# ['neuron_1k_v2', 'neuron_1k_v3', 'neuron_10k_v3']

# %%
dir_string
# Out:
# './fits/gg_221119_025_neuron_noisefree_1'

# %%
result_strings
# Out:
# ['./fits/gg_221119_025_neuron_noisefree_1/neuron_1k_v2/Bursty_None_1x1/grid_scan_results.res',
#  './fits/gg_221119_025_neuron_noisefree_1/neuron_1k_v3/Bursty_None_1x1/grid_scan_results.res',
#  './fits/gg_221119_025_neuron_noisefree_1/neuron_10k_v3/Bursty_None_1x1/grid_scan_results.res']

# %%
sr_arr = []
sd_arr = []
for i in range(n_datasets):
    sr = monod.analysis.load_search_results(result_strings[i])
    sd = monod.analysis.load_search_data(dir_string+'/'+dataset_names[i]+'/raw.sd')
    sr.find_sampling_optimum()

    fig1,ax1 = plt.subplots(1,1)
    sr.plot_KL(ax1)

    sr.plot_gene_distributions(sd,marg='joint')

    _=sr.chisquare_testing(sd,threshold=0.01)

    sr.compute_sigma(sd,num_cores=60)
    sr.plot_param_L_dep(plot_errorbars=True,plot_fit=True)
    sr.plot_param_marg()
    
    monod.analysis.make_batch_analysis_dir([sr],dir_string)
    sr.update_on_disk()
    
    sr_arr.append(sr)
    sd_arr.append(sd)
# Out:
# INFO:root:Grid scan results loaded from ./fits/gg_221119_025_neuron_noisefree_1/neuron_1k_v2/Bursty_None_1x1/grid_scan_results.res.
# INFO:root:Search data loaded from ./fits/gg_221119_025_neuron_noisefree_1/neuron_1k_v2/raw.sd.
# INFO:root:No rejection statistics have been computed.
# INFO:root:Figure stored to ./fits/gg_221119_025_neuron_noisefree_1/neuron_1k_v2/Bursty_None_1x1/analysis_figures/kldiv.png.
# INFO:root:Figure stored to ./fits/gg_221119_025_neuron_noisefree_1/neuron_1k_v2/Bursty_None_1x1/analysis_figures/gene_distributions_joint.png.
# INFO:root:Chi-square computation complete. Rejected 119 genes out of 2500. Runtime: 4.3 seconds.
# INFO:root:Computing local Hessian.
# INFO:root:Starting parallelized Hessian computation.
# INFO:root:Parallelized Hessian computation complete.
# INFO:root:Gene 10 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 258 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 419 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 463 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 484 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 571 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 644 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 701 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 763 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 786 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 902 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 953 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1003 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1120 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1236 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1319 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1372 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1412 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1604 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1622 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1653 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1715 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1775 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1798 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1803 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1848 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1955 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1959 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1970 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1975 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2071 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2183 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2214 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2232 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2246 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2370 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2413 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2424 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Standard error of the MLE computation complete. Runtime: 42.4 seconds.
# /home/ggorin/projects/monod/src/monod/inference.py:1354: RuntimeWarning: invalid value encountered in sqrt
#   sigma[gene_index, :] = np.sqrt(np.diag(hess_inv)) / np.sqrt(
# INFO:root:Figure stored to ./fits/gg_221119_025_neuron_noisefree_1/neuron_1k_v2/Bursty_None_1x1/analysis_figures/length_dependence.png.
# INFO:root:Figure stored to ./fits/gg_221119_025_neuron_noisefree_1/neuron_1k_v2/Bursty_None_1x1/analysis_figures/parameter_marginals.png.
# INFO:root:Directory ./fits/gg_221119_025_neuron_noisefree_1/analysis_figures created.
# INFO:root:Grid scan results loaded from ./fits/gg_221119_025_neuron_noisefree_1/neuron_1k_v3/Bursty_None_1x1/grid_scan_results.res.
# INFO:root:Search data loaded from ./fits/gg_221119_025_neuron_noisefree_1/neuron_1k_v3/raw.sd.
# INFO:root:No rejection statistics have been computed.
# INFO:root:Figure stored to ./fits/gg_221119_025_neuron_noisefree_1/neuron_1k_v3/Bursty_None_1x1/analysis_figures/kldiv.png.
# INFO:root:Figure stored to ./fits/gg_221119_025_neuron_noisefree_1/neuron_1k_v3/Bursty_None_1x1/analysis_figures/gene_distributions_joint.png.
# INFO:root:Chi-square computation complete. Rejected 390 genes out of 2500. Runtime: 7.3 seconds.
# INFO:root:Computing local Hessian.
# INFO:root:Starting parallelized Hessian computation.
# INFO:root:Parallelized Hessian computation complete.
# INFO:root:Gene 43 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 167 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 184 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 258 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 341 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 460 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 484 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 494 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 679 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 902 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1003 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1105 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1115 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1190 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1319 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1393 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1400 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1406 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1412 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1587 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1666 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1713 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1732 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1849 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1951 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1970 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2123 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2156 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2214 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2257 ran into singularity; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2320 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2413 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2422 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2424 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Standard error of the MLE computation complete. Runtime: 61.0 seconds.
# /home/ggorin/projects/monod/src/monod/inference.py:1354: RuntimeWarning: invalid value encountered in sqrt
#   sigma[gene_index, :] = np.sqrt(np.diag(hess_inv)) / np.sqrt(
# INFO:root:Figure stored to ./fits/gg_221119_025_neuron_noisefree_1/neuron_1k_v3/Bursty_None_1x1/analysis_figures/length_dependence.png.
# INFO:root:Figure stored to ./fits/gg_221119_025_neuron_noisefree_1/neuron_1k_v3/Bursty_None_1x1/analysis_figures/parameter_marginals.png.
# INFO:root:Directory ./fits/gg_221119_025_neuron_noisefree_1/analysis_figures already exists.
# INFO:root:Grid scan results loaded from ./fits/gg_221119_025_neuron_noisefree_1/neuron_10k_v3/Bursty_None_1x1/grid_scan_results.res.
# INFO:root:Search data loaded from ./fits/gg_221119_025_neuron_noisefree_1/neuron_10k_v3/raw.sd.
# INFO:root:No rejection statistics have been computed.
# INFO:root:Figure stored to ./fits/gg_221119_025_neuron_noisefree_1/neuron_10k_v3/Bursty_None_1x1/analysis_figures/kldiv.png.
# INFO:root:Figure stored to ./fits/gg_221119_025_neuron_noisefree_1/neuron_10k_v3/Bursty_None_1x1/analysis_figures/gene_distributions_joint.png.
# INFO:root:Chi-square computation complete. Rejected 75 genes out of 2500. Runtime: 8.8 seconds.
# INFO:root:Computing local Hessian.
# INFO:root:Starting parallelized Hessian computation.
# INFO:root:Parallelized Hessian computation complete.
# INFO:root:Gene 69 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 128 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 167 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 320 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 354 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 419 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 433 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 463 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 484 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 737 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 777 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 781 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 902 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 981 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1075 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1171 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1180 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1190 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1319 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1375 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1412 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1519 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1571 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1578 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1653 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1666 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1713 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1756 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1798 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1847 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1880 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1951 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 1955 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2075 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2083 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2123 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2246 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2412 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2413 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Gene 2456 gives negative stdev; replaced with mean. (Search converged to local minimum?)
# INFO:root:Standard error of the MLE computation complete. Runtime: 338.3 seconds.
# /home/ggorin/projects/monod/src/monod/inference.py:1354: RuntimeWarning: invalid value encountered in sqrt
#   sigma[gene_index, :] = np.sqrt(np.diag(hess_inv)) / np.sqrt(
# INFO:root:Figure stored to ./fits/gg_221119_025_neuron_noisefree_1/neuron_10k_v3/Bursty_None_1x1/analysis_figures/length_dependence.png.
# INFO:root:Figure stored to ./fits/gg_221119_025_neuron_noisefree_1/neuron_10k_v3/Bursty_None_1x1/analysis_figures/parameter_marginals.png.
# INFO:root:Directory ./fits/gg_221119_025_neuron_noisefree_1/analysis_figures already exists.
